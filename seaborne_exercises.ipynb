# %% [markdown]
# # Exercises

# %% [markdown]
# Create a file named seaborn_exercises.py or seaborn_exercises.ipynb for this exercise.
# Use the iris database to answer the following quesitons:

# %% [markdown]
# 1. What does the distribution of petal lengths look like?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pydataset import data

# %%
# %matplotlib inline

# %%
jimmy = sns.load_dataset('iris')

# %%
jimmy.shape
# Out:
# (150, 5)

# %%
jimmy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
jimmy.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# # James' Presentation
#
# - Show him Python

# %%
sns.histplot(data=jimmy, x='petal_length',kde=True)
plt.show()

# %% [markdown]
# # MVP

# %% [markdown]
# ## Minimum Viable Product

# %% [markdown]
# ### Minimum Effective Dose

# %%
1.5 pills vs 2 pills

# %%
sns.displot(iris["petal_length"], kde=True)
#sns.histplot(tips["petal_length", kde == True])
plt.show()

# %% [markdown]
# 2. Is there a correlation between petal length and petal width? Use http://guessthecorrelation.com/ as a hint to how we could visually determine if a correlation exists between two numeric columns.

# %%
sns.relplot(data=iris, x='petal_length', y='petal_width', hue='species')
plt.show()

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris)
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_corr = iris.corr() #correlation ? # = 1.0000 ?
iris_corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
petal_lengthwidth = pd.crosstab(iris_corr["petal_length"], iris_corr["petal_width"])

sns.heatmap(petal_lengthwidth,annot=False)
plt.show()

# %% [markdown]
# 3. Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.

# %%
iris.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
sns.relplot(x="sepal_length",y="sepal_width",data=iris,hue="species")
plt.show()

# %% [markdown]
# 4. Which features would be best used to predict species?

# %%
sample_data = iris.head(100)
sns.pairplot(data = sample_data, hue='species')

# %%
sepals_tab = pd.crosstab(iris["sepal_length"], iris["sepal_width"], normalize=True)
# Out:
# sepal_width        2.0       2.2       2.3       2.4       2.5       2.6  \
# sepal_length
# 4.3           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4.4           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4.5           0.000000  0.000000  0.006667  0.000000  0.000000  0.000000
# 4.6           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4.7           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4.8           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4.9           0.000000  0.000000  0.000000  0.006667  0.006667  0.000000
# 5.0           0.006667  0.000000  0.006667  0.000000  0.000000  0.000000
# 5.1           0.000000  0.000000  0.000000  0.000000  0.006667  0.000000
# 5.2           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5.3           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5.4           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5.5           0.000000  0.000000  0.006667  0.013333  0.006667  0.006667
# 5.6           0.000000  0.000000  0.000000  0.000000  0.006667  0.000000
# 5.7           0.000000  0.000000  0.000000  0.000000  0.006667  0.006667
# 5.8           0.000000  0.000000  0.000000  0.000000  0.000000  0.006667
# 5.9           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.0           0.000000  0.013333  0.000000  0.000000  0.000000  0.000000
# 6.1           0.000000  0.000000  0.000000  0.000000  0.000000  0.006667
# 6.2           0.000000  0.006667  0.000000  0.000000  0.000000  0.000000
# 6.3           0.000000  0.000000  0.006667  0.000000  0.013333  0.000000
# 6.4           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.5           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.6           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.7           0.000000  0.000000  0.000000  0.000000  0.006667  0.000000
# 6.8           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.9           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.0           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.1           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.2           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.3           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.4           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.6           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.7           0.000000  0.000000  0.000000  0.000000  0.000000  0.006667
# 7.9           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# sepal_width        2.7       2.8       2.9       3.0  ...       3.4       3.5  \
# sepal_length                                          ...
# 4.3           0.000000  0.000000  0.000000  0.006667  ...  0.000000  0.000000
# 4.4           0.000000  0.000000  0.006667  0.006667  ...  0.000000  0.000000
# 4.5           0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 4.6           0.000000  0.000000  0.000000  0.000000  ...  0.006667  0.000000
# 4.7           0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 4.8           0.000000  0.000000  0.000000  0.013333  ...  0.013333  0.000000
# 4.9           0.000000  0.000000  0.000000  0.006667  ...  0.000000  0.000000
# 5.0           0.000000  0.000000  0.000000  0.006667  ...  0.013333  0.013333
# 5.1           0.000000  0.000000  0.000000  0.000000  ...  0.006667  0.013333
# 5.2           0.006667  0.000000  0.000000  0.000000  ...  0.006667  0.006667
# 5.3           0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 5.4           0.000000  0.000000  0.000000  0.006667  ...  0.013333  0.000000
# 5.5           0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.006667
# 5.6           0.006667  0.006667  0.006667  0.013333  ...  0.000000  0.000000
# 5.7           0.000000  0.013333  0.006667  0.006667  ...  0.000000  0.000000
# 5.8           0.026667  0.006667  0.000000  0.000000  ...  0.000000  0.000000
# 5.9           0.000000  0.000000  0.000000  0.013333  ...  0.000000  0.000000
# 6.0           0.006667  0.000000  0.006667  0.006667  ...  0.006667  0.000000
# 6.1           0.000000  0.013333  0.006667  0.013333  ...  0.000000  0.000000
# 6.2           0.000000  0.006667  0.006667  0.000000  ...  0.006667  0.000000
# 6.3           0.006667  0.006667  0.006667  0.000000  ...  0.006667  0.000000
# 6.4           0.006667  0.013333  0.006667  0.000000  ...  0.000000  0.000000
# 6.5           0.000000  0.006667  0.000000  0.020000  ...  0.000000  0.000000
# 6.6           0.000000  0.000000  0.006667  0.006667  ...  0.000000  0.000000
# 6.7           0.000000  0.000000  0.000000  0.013333  ...  0.000000  0.000000
# 6.8           0.000000  0.006667  0.000000  0.006667  ...  0.000000  0.000000
# 6.9           0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 7.0           0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 7.1           0.000000  0.000000  0.000000  0.006667  ...  0.000000  0.000000
# 7.2           0.000000  0.000000  0.000000  0.006667  ...  0.000000  0.000000
# 7.3           0.000000  0.000000  0.006667  0.000000  ...  0.000000  0.000000
# 7.4           0.000000  0.006667  0.000000  0.000000  ...  0.000000  0.000000
# 7.6           0.000000  0.000000  0.000000  0.006667  ...  0.000000  0.000000
# 7.7           0.000000  0.006667  0.000000  0.006667  ...  0.000000  0.000000
# 7.9           0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
#
# sepal_width        3.6       3.7       3.8       3.9       4.0       4.1  \
# sepal_length
# 4.3           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4.4           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4.5           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4.6           0.006667  0.000000  0.000000  0.000000  0.000000  0.000000
# 4.7           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4.8           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4.9           0.006667  0.000000  0.000000  0.000000  0.000000  0.000000
# 5.0           0.006667  0.000000  0.000000  0.000000  0.000000  0.000000
# 5.1           0.000000  0.006667  0.020000  0.000000  0.000000  0.000000
# 5.2           0.000000  0.000000  0.000000  0.000000  0.000000  0.006667
# 5.3           0.000000  0.006667  0.000000  0.000000  0.000000  0.000000
# 5.4           0.000000  0.006667  0.000000  0.013333  0.000000  0.000000
# 5.5           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5.6           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5.7           0.000000  0.000000  0.006667  0.000000  0.000000  0.000000
# 5.8           0.000000  0.000000  0.000000  0.000000  0.006667  0.000000
# 5.9           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.0           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.1           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.2           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.3           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.4           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.5           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.6           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.7           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.8           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6.9           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.0           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.1           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.2           0.006667  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.3           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.4           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.6           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7.7           0.000000  0.000000  0.006667  0.000000  0.000000  0.000000
# 7.9           0.000000  0.000000  0.006667  0.000000  0.000000  0.000000
#
# sepal_width        4.2       4.4
# sepal_length
# 4.3           0.000000  0.000000
# 4.4           0.000000  0.000000
# 4.5           0.000000  0.000000
# 4.6           0.000000  0.000000
# 4.7           0.000000  0.000000
# 4.8           0.000000  0.000000
# 4.9           0.000000  0.000000
# 5.0           0.000000  0.000000
# 5.1           0.000000  0.000000
# 5.2           0.000000  0.000000
# 5.3           0.000000  0.000000
# 5.4           0.000000  0.000000
# 5.5           0.006667  0.000000
# 5.6           0.000000  0.000000
# 5.7           0.000000  0.006667
# 5.8           0.000000  0.000000
# 5.9           0.000000  0.000000
# 6.0           0.000000  0.000000
# 6.1           0.000000  0.000000
# 6.2           0.000000  0.000000
# 6.3           0.000000  0.000000
# 6.4           0.000000  0.000000
# 6.5           0.000000  0.000000
# 6.6           0.000000  0.000000
# 6.7           0.000000  0.000000
# 6.8           0.000000  0.000000
# 6.9           0.000000  0.000000
# 7.0           0.000000  0.000000
# 7.1           0.000000  0.000000
# 7.2           0.000000  0.000000
# 7.3           0.000000  0.000000
# 7.4           0.000000  0.000000
# 7.6           0.000000  0.000000
# 7.7           0.000000  0.000000
# 7.9           0.000000  0.000000
#
# [35 rows x 23 columns]

# %%
sepals_tab = pd.crosstab(iris["sepal_length"], iris["sepal_width"], normalize=True)
sns.heatmap(sepals_tab,cmap=plt.cm.plasma)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# 1. Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?

# %%
df = sns.load_dataset("anscombe")
df.groupby(['dataset']).describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 2. Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
dataset_1 = df[df['dataset']=='I'][['x']].head()
dataset_2 = df[df['dataset']=='II'][['x']].head()
dataset_3 = df[df['dataset']=='III'][['x']].head()
dataset_4 = df[df['dataset']=='IV'][['x']].head()

print(df.groupby('dataset').head(1))

print(dataset_1.head(3))
print(dataset_2.head(3))
print(dataset_3.head(3))
print(dataset_4.head(3))

# for Loop

# List Comprehension

#sns.get_data_set_names()

#df[(df['dataset'] == 'I') & (df['x'] < 10)]
# Out:
#    dataset     x     y
# 0        I  10.0  8.04
# 11      II  10.0  9.14
# 22     III  10.0  7.46
# 33      IV   8.0  6.58
#       x
# 0  10.0
# 1   8.0
# 2  13.0
#        x
# 11  10.0
# 12   8.0
# 13  13.0
#        x
# 22  10.0
# 23   8.0
# 24  13.0
#       x
# 33  8.0
# 34  8.0
# 35  8.0

# %%
sns.relplot(data=df,x="x", y="y",col="dataset")
plt.show()

# %% [markdown]
# 3. Load the InsectSprays dataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
bugs = data("InsectSprays")

# %%
data("InsectSprays",show_doc=True)
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
#     summary(fm1)
#     opar <- par(mfrow = c(2, 2), oma = c(0, 0, 1.1, 0))
#     plot(fm1)
#     fm2 <- aov(sqrt(count) ~ spray, data = InsectSprays)
#     summary(fm2)
#     plot(fm2)
#     par(opar)

# %%
bugs.head()
# Out:
#    count spray
# 1     10     A
# 2      7     A
# 3     20     A
# 4     14     A
# 5     14     A

# %%
# sns.boxplot(data=df, x="age", y="class")

# %%
sns.boxplot(data=bugs,x="spray",y="count")
plt.show()

# %% [markdown]
# 4. Load the swiss dataset and read it's documentation. The swiss dataset is available from pydatset rather than seaborn. Create visualizations to answer the following questions:

# %%
swiss_dataset = data("swiss")

# %%
data("swiss",show_doc=True)
# Out:
# swiss
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Swiss Fertility and Socioeconomic Indicators (1888) Data
#
# ### Description
#
# Standardized fertility measure and socio-economic indicators for each of 47
# French-speaking provinces of Switzerland at about 1888.
#
# ### Usage
#
#     data(swiss)
#
# ### Format
#
# A data frame with 47 observations on 6 variables, each of which is in percent,
# i.e., in [0,100].
#
# [,1] Fertility Ig, "common standardized fertility measure" [,2] Agriculture
# [,3] Examination nation [,4] Education [,5] Catholic [,6] Infant.Mortality
# live births who live less than 1 year.
#
# All variables but 'Fert' give proportions of the population.
#
# ### Source
#
# Project "16P5", pages 549-551 in
#
# Mosteller, F. and Tukey, J. W. (1977) “Data Analysis and Regression: A Second
# Course in Statistics”. Addison-Wesley, Reading Mass.
#
# indicating their source as "Data used by permission of Franice van de Walle.
# Office of Population Research, Princeton University, 1976\. Unpublished data
# assembled under NICHD contract number No 1-HD-O-2077."
#
# ### References
#
# Becker, R. A., Chambers, J. M. and Wilks, A. R. (1988) “The New S Language”.
# Wadsworth & Brooks/Cole.

# %% [markdown]
# - Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
swiss_dataset.head(1)
# Out:
#             Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary       80.2         17.0           15         12      9.96
#
#             Infant.Mortality
# Courtelary              22.2

# %%
swiss_dataset["is_catholic"] = swiss_dataset["Catholic"] > 50

# %%
swiss_dataset.head(1)
# Out:
#             Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary       80.2         17.0           15         12      9.96
#
#             Infant.Mortality  is_catholic
# Courtelary              22.2        False

# %% [markdown]
# - Does whether or not a province is Catholic influence fertility?

# %%
swiss_fertility = pd.crosstab(swiss_dataset["Fertility"],swiss_dataset["is_catholic"])
sns.heatmap(swiss_fertility,cmap=plt.cm.plasma)
plt.show()

# %% [markdown]
# - What measure correlates most strongly with fertility?

# %%
swiss_dataset.corr()
# Out:
#                   Fertility  Agriculture  Examination  Education  Catholic  \
# Fertility          1.000000     0.353079    -0.645883  -0.663789  0.463685
# Agriculture        0.353079     1.000000    -0.686542  -0.639523  0.401095
# Examination       -0.645883    -0.686542     1.000000   0.698415 -0.572742
# Education         -0.663789    -0.639523     0.698415   1.000000 -0.153859
# Catholic           0.463685     0.401095    -0.572742  -0.153859  1.000000
# Infant.Mortality   0.416556    -0.060859    -0.114022  -0.099322  0.175496
# is_catholic        0.402813     0.410503    -0.597861  -0.154677  0.961723
#
#                   Infant.Mortality  is_catholic
# Fertility                 0.416556     0.402813
# Agriculture              -0.060859     0.410503
# Examination              -0.114022    -0.597861
# Education                -0.099322    -0.154677
# Catholic                  0.175496     0.961723
# Infant.Mortality          1.000000     0.166081
# is_catholic               0.166081     1.000000

# %% [markdown]
# - Using the chipotle dataset from the previous exercise, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
from env import host, username, password

# %%
def get_db_url(u,p,h,d):
    url = f'mysql+pymysql://{u}:{p}@{h}/{d}'
    return url

# %%
# MY SQL SETUP

host = host
user = username
password = password

chipotle_url = get_db_url(user,password,host,"chipotle")
chipotle_url
chipotle_df = pd.read_sql('SELECT * FROM orders', chipotle_url)

# %%
chipotle_df.columns
# Out:
# Index(['id', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipotle_df['item_price'] = chipotle_df['item_price'].str.replace("$","").astype(float)
# Out:
# /var/folders/_r/wftd7dk93nj_hbzpqfw4vnsr0000gn/T/ipykernel_35719/3058103404.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chipotle_df['item_price'] = chipotle_df['item_price'].str.replace("$","").astype(float)

# %%
chipotle_df['item_price']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
most_orders = chipotle_df.groupby("item_name").agg({"id":"count","item_price":"sum"})

# %%
type(most_orders)
# Out:
# pandas.core.frame.DataFrame

# %%
most_orders_total = chipotle_df.groupby("item_name")[['item_price']].sum().head(4)

# %%
most_orders_total
# Out:
#                        item_price
# item_name
# 6 Pack Soft Drink          356.95
# Barbacoa Bowl              672.36
# Barbacoa Burrito           894.75
# Barbacoa Crispy Tacos      120.21

# %%
most_orders.sort_values(by="id",ascending=False).head()
# Out:
#                       id  item_price
# item_name
# Chicken Bowl         726     7342.73
# Chicken Burrito      553     5575.82
# Chips and Guacamole  479     2201.04
# Steak Burrito        368     3851.43
# Canned Soft Drink    301      438.75

# %%
top_four_items = most_orders.sort_values(by="id",ascending=False).head(4)

# %%
top_four_items
# Out:
#                       id  item_price
# item_name
# Chicken Bowl         726     7342.73
# Chicken Burrito      553     5575.82
# Chips and Guacamole  479     2201.04
# Steak Burrito        368     3851.43

# %%
sns.barplot(x="id",y="item_price",data=top_four_items)
plt.show()

# %% [markdown]
# 5. Load the sleepstudy data and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
sleepstudy = data("sleepstudy")

# %%
data("sleepstudy",show_doc=True)
# Out:
# sleepstudy
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Reaction times in a sleep deprivation study
#
# ### Description
#
# The average reaction time per day for subjects in a sleep deprivation study.
# On day 0 the subjects had their normal amount of sleep. Starting that night
# they were restricted to 3 hours of sleep per night. The observations represent
# the average reaction time on a series of tests given each day to each subject.
#
# ### Format
#
# A data frame with 180 observations on the following 3 variables.
#
# `Reaction`
#
# Average reaction time (ms)
#
# `Days`
#
# Number of days of sleep deprivation
#
# `Subject`
#
# Subject number on which the observation was made.
#
# ### Details
#
# These data are from the study described in Belenky et al. (2003), for the
# sleep-deprived group and for the first 10 days of the study, up to the
# recovery period.
#
# ### References
#
# Gregory Belenky, Nancy J. Wesensten, David R. Thorne, Maria L. Thomas, Helen
# C. Sing, Daniel P. Redmond, Michael B. Russo and Thomas J. Balkin (2003)
# Patterns of performance degradation and restoration during sleep restriction
# and subsequent recovery: a sleep dose-response study. _Journal of Sleep
# Research_ **12**, 1–12.
#
# ### Examples
#
#     str(sleepstudy)
#     require(lattice)
#     xyplot(Reaction ~ Days | Subject, sleepstudy, type = c("g","p","r"),
#            index = function(x,y) coef(lm(y ~ x))[1],
#            xlab = "Days of sleep deprivation",
#            ylab = "Average reaction time (ms)", aspect = "xy")
#     (fm1 <- lmer(Reaction ~ Days + (Days|Subject), sleepstudy))
#     (fm2 <- lmer(Reaction ~ Days + (1|Subject) + (0+Days|Subject), sleepstudy))

# %%
sleepstudy.head()
# Out:
#    Reaction  Days  Subject
# 1  249.5600     0      308
# 2  258.7047     1      308
# 3  250.8006     2      308
# 4  321.4398     3      308
# 5  356.8519     4      308

# %%
sleepstudy['Subject'].unique()
# Out:
# array([308, 309, 310, 330, 331, 332, 333, 334, 335, 337, 349, 350, 351,
#        352, 369, 370, 371, 372])

# %%
sns.lineplot(x="Days", y="Reaction",hue="Subject",data=sleepstudy)
plt.show()
